# %% [markdown]
# # Assignment 3: CNN implementation (LeNet-5)
#
# This notebook implements a modified LeNet-5 for MNIST using the required training settings.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

# %%
# Load MNIST
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)

# Combine so we can split later
x_combined = np.concatenate([x_train, x_test], axis=0)
y_combined = np.concatenate([y_train, y_test], axis=0)

# Normalize
x_combined = x_combined.astype("float32") / 255.0

# 70/30 split
x_train, x_test, y_train, y_test = train_test_split(
    x_combined, y_combined, test_size=0.30, random_state=7, stratify=y_combined
)

x_train.shape, x_test.shape
# Out:
# ((49000, 28, 28), (21000, 28, 28))

# %% [markdown]
# ## Task 1: Implement your own LeNet-5 for MNIST

# %%
# Build my version of the LeNet-5
model = keras.Sequential([
    layers.Input(shape=(28, 28, 1)),
    layers.Conv2D(filters=12, kernel_size=3, activation='relu', padding='same'),
    layers.AvgPool2D(pool_size=2, strides=2),
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='valid'),
    layers.AvgPool2D(pool_size=2, strides=2),
    layers.Flatten(),
    layers.Dense(120, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.Dense(84, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=2e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 12)     │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 14, 14, 12)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 32)     │         3,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 6, 6, 32)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 120)            │       138,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 152,982 (597.59 KB)
#  Trainable params: 152,982 (597.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train
history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(x_test, y_test),
    verbose=2
)
# Out:
# Epoch 1/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.7310 - loss: 0.8537 - val_accuracy: 0.9394 - val_loss: 0.2460
# Epoch 2/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9080 - loss: 0.3432 - val_accuracy: 0.9582 - val_loss: 0.1725
# Epoch 3/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9383 - loss: 0.2512 - val_accuracy: 0.9689 - val_loss: 0.1364
# Epoch 4/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9491 - loss: 0.2133 - val_accuracy: 0.9723 - val_loss: 0.1226
# Epoch 5/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9573 - loss: 0.1832 - val_accuracy: 0.9753 - val_loss: 0.1148
# Epoch 6/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9611 - loss: 0.1695 - val_accuracy: 0.9770 - val_loss: 0.1092
# Epoch 7/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9641 - loss: 0.1554 - val_accuracy: 0.9786 - val_loss: 0.1013
# Epoch 8/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9681 - loss: 0.1453 - val_accuracy: 0.9799 - val_loss: 0.1032
# Epoch 9/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9697 - loss: 0.1366 - val_accuracy: 0.9810 - val_loss: 0.0960
# Epoch 10/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9725 - loss: 0.1304 - val_accuracy: 0.9822 - val_loss: 0.0924
# Epoch 11/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9744 - loss: 0.1221 - val_accuracy: 0.9821 - val_loss: 0.0916
# Epoch 12/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9759 - loss: 0.1166 - val_accuracy: 0.9844 - val_loss: 0.0862
# Epoch 13/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9781 - loss: 0.1116 - val_accuracy: 0.9836 - val_loss: 0.0845
# Epoch 14/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9775 - loss: 0.1095 - val_accuracy: 0.9831 - val_loss: 0.0873
# Epoch 15/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9793 - loss: 0.1029 - val_accuracy: 0.9849 - val_loss: 0.0866
# Epoch 16/50
# 1532/1532 - 4s - 3ms/step - accuracy: 0.9798 - loss: 0.1011 - val_accuracy: 0.9862 - val_loss: 0.0792
# Epoch 17/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9809 - loss: 0.0986 - val_accuracy: 0.9851 - val_loss: 0.0812
# Epoch 18/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9816 - loss: 0.0959 - val_accuracy: 0.9867 - val_loss: 0.0755
# Epoch 19/50
# 1532/1532 - 6s - 4ms/step - accuracy: 0.9819 - loss: 0.0933 - val_accuracy: 0.9862 - val_loss: 0.0768
# Epoch 20/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9823 - loss: 0.0918 - val_accuracy: 0.9869 - val_loss: 0.0760
# Epoch 21/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9834 - loss: 0.0879 - val_accuracy: 0.9878 - val_loss: 0.0736
# Epoch 22/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9837 - loss: 0.0861 - val_accuracy: 0.9875 - val_loss: 0.0702
# Epoch 23/50
# 1532/1532 - 6s - 4ms/step - accuracy: 0.9844 - loss: 0.0841 - val_accuracy: 0.9880 - val_loss: 0.0715
# Epoch 24/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9850 - loss: 0.0816 - val_accuracy: 0.9872 - val_loss: 0.0717
# Epoch 25/50
# 1532/1532 - 4s - 3ms/step - accuracy: 0.9851 - loss: 0.0797 - val_accuracy: 0.9879 - val_loss: 0.0700
# Epoch 26/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9857 - loss: 0.0774 - val_accuracy: 0.9882 - val_loss: 0.0698
# Epoch 27/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9856 - loss: 0.0764 - val_accuracy: 0.9881 - val_loss: 0.0689
# Epoch 28/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9863 - loss: 0.0750 - val_accuracy: 0.9882 - val_loss: 0.0689
# Epoch 29/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9862 - loss: 0.0738 - val_accuracy: 0.9870 - val_loss: 0.0721
# Epoch 30/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9882 - loss: 0.0691 - val_accuracy: 0.9885 - val_loss: 0.0674
# Epoch 31/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9873 - loss: 0.0713 - val_accuracy: 0.9881 - val_loss: 0.0685
# Epoch 32/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9867 - loss: 0.0713 - val_accuracy: 0.9890 - val_loss: 0.0682
# Epoch 33/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9868 - loss: 0.0696 - val_accuracy: 0.9895 - val_loss: 0.0656
# Epoch 34/50
# 1532/1532 - 6s - 4ms/step - accuracy: 0.9885 - loss: 0.0675 - val_accuracy: 0.9887 - val_loss: 0.0688
# Epoch 35/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9882 - loss: 0.0657 - val_accuracy: 0.9895 - val_loss: 0.0643
# Epoch 36/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9881 - loss: 0.0661 - val_accuracy: 0.9887 - val_loss: 0.0661
# Epoch 37/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9882 - loss: 0.0651 - val_accuracy: 0.9897 - val_loss: 0.0643
# Epoch 38/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9888 - loss: 0.0637 - val_accuracy: 0.9889 - val_loss: 0.0667
# Epoch 39/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9896 - loss: 0.0618 - val_accuracy: 0.9893 - val_loss: 0.0662
# Epoch 40/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9889 - loss: 0.0625 - val_accuracy: 0.9893 - val_loss: 0.0672
# Epoch 41/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9893 - loss: 0.0613 - val_accuracy: 0.9903 - val_loss: 0.0629
# Epoch 42/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9893 - loss: 0.0599 - val_accuracy: 0.9902 - val_loss: 0.0622
# Epoch 43/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9901 - loss: 0.0576 - val_accuracy: 0.9894 - val_loss: 0.0637
# Epoch 44/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9899 - loss: 0.0583 - val_accuracy: 0.9900 - val_loss: 0.0621
# Epoch 45/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9899 - loss: 0.0609 - val_accuracy: 0.9902 - val_loss: 0.0605
# Epoch 46/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9896 - loss: 0.0579 - val_accuracy: 0.9892 - val_loss: 0.0648
# Epoch 47/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9898 - loss: 0.0566 - val_accuracy: 0.9898 - val_loss: 0.0627
# Epoch 48/50
# 1532/1532 - 5s - 3ms/step - accuracy: 0.9904 - loss: 0.0564 - val_accuracy: 0.9909 - val_loss: 0.0604
# Epoch 49/50
# 1532/1532 - 5s - 4ms/step - accuracy: 0.9907 - loss: 0.0561 - val_accuracy: 0.9898 - val_loss: 0.0624
# Epoch 50/50
# 1532/1532 - 6s - 4ms/step - accuracy: 0.9900 - loss: 0.0560 - val_accuracy: 0.9906 - val_loss: 0.0610

# %%
# Evaluate training and testing accuracy
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

print(f'Training accuracy: {train_acc:.4f}')
print(f'Testing accuracy:  {test_acc:.4f}')
# Out:
# Training accuracy: 0.9976
# Testing accuracy:  0.9906

# %% [markdown]
# It seems like my implementation of LeNet performs quite well on both the training and testing samples. With less than a 1% dropoff between the two.
